# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
# %matplotlib inline

# %%
df = pd.read_csv('POPs_MamiferosMarinhos_02ago.csv', index_col= 0)
#df.index = make_index(df)
df.head()
# Out:
#        REF Regiao Estado               Area_Estudo            Referencia  \
# COD
# A01  POP01     SE     RJ     Baía de Guanabara- RJ  Da Silva et al. 2003
# A02  POP01     SE     RJ     Baía de Guanabara- RJ  Da Silva et al. 2003
# A03  POP02     SE     SP  Estuário de Cananéia- SP     Yogui et al. 2003
# A04  POP02     SE     SP  Estuário de Cananéia- SP     Yogui et al. 2003
# A05  POP02     SE     SP  Estuário de Cananéia- SP     Yogui et al. 2003
#
#       Longitude    Latitude  n_amostral             Especie      Nome comum  \
# COD
# A01   43.13792W   22.78052S           1  Sotalia guianensis  Guiana Dolphin
# A02   43.13792W   22.78052S           1  Sotalia guianensis  Guiana Dolphin
# A03  47.929726W  25.053629S           1  Sotalia guianensis  Guiana Dolphin
# A04  47.929726W  25.053629S           1  Sotalia guianensis  Guiana Dolphin
# A05  47.929726W  25.053629S           1  Sotalia guianensis  Guiana Dolphin
#
# ...

# %%
df = df.dropna()
df = df.loc[df["Longitude"] != "Longitude"]

df[["Longitude", "Latitude"]]
# Out:
# Empty DataFrame
# Columns: [Longitude, Latitude]
# Index: []
